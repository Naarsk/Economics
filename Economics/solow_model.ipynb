# %%
from Economics.solow_model import Solow, CobbDouglas

cobb_douglas = CobbDouglas(alpha=0.5)

cobb_douglas(x=[5,2])
# Out:
# 3.1622776601683795

# %%
def logistic_map(x):
    return 3.2 * x * (1-x/200)

def exponential_growth(x):
    return (1+0.02) * x

# %%
solow_model = Solow(saving_rate=0.3, depreciation_rate=0.02, starting_capital=100, production_function=cobb_douglas, starting_pop_level=150,labor_growth_function=logistic_map)

df=solow_model.evaluate()

print(df.to_string());
# Out:
#      time       capital       labor       income  income_per_cap  capital_per_cap     rates     wages
# 0       0    100.000000  150.000000   122.474487        0.816497         0.666667  0.612372  0.408249
# 1       1    134.742346  120.000000   127.157703        1.059648         1.122853  0.471856  0.529824
# 2       2    170.194810  153.600000   161.684640        1.052634         1.108039  0.474998  0.526320
# 3       3    215.296306  114.032640   156.686969        1.374054         1.888024  0.363888  0.687025
# 4       4    257.996471  156.849360   201.163072        1.282524         1.644868  0.389856  0.641264
# 5       5    313.185463  108.290404   184.160203        1.700614         2.892089  0.294012  0.850307
# 6       6    362.169814  158.900307   239.893507        1.509711         2.279227  0.331190  0.754858
# 7       7    426.894470  104.492061   211.203890        2.021243         4.085425  0.247372  1.010622
# ...

# %%
df[['labor']].plot()
df[['income']].plot()
df[['capital']].plot()
df[['wages']].plot()
df[['income_per_cap']].plot()
df[['capital_per_cap']].plot()
df[['rates']].plot()
# Out:
# <Axes: >
